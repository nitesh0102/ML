# %%
Q1. Explain the concept of R-squared in linear regression models. How is it calculated, and what does it
represent?

# %%
Ans: R-squared is a method to understand how good the model has predicted the values. 
    
It is a statistical measure that represents the goodness of fit of a regression model. 

Lies between 0 t0 1.

1 = Perfectly fit model and there is no difference between actual and predicted value. 
0 = Model does not predict any variability in the model and it does not learn any relation 
between the dependent and independent variable

# %%
R Sqaure is also known as coefficient of determination.

# %%
How to Calculate R-Squared : 

1. Find the mean of Y 
2. Calculate SS tot  by    Sigma 1 to n (Y i - Ymean)^2
3. Estimate the model parameter 
4. Calculate SSres by using the model parameter (The best fit line) by finding the 
difference between model parameter and the actual value
* The residual sum of squares is calculated by the summation of squares of perpendicular distance between data points and the best-fitted line. 
5. R^2 = 1 - SS res/SS tot

# %%
The goodness of fit of regression models can be analyzed on the basis of the R-square method. The more the value of the r-square near 1, the better the model is. 

Note: The value of R-square can also be negative when the model fitted is worse than the average fitted model.

# %%
Q2. Define adjusted R-squared and explain how it differs from the regular R-squared.

# %%
Limitation of using the R-square method –
The value of r-square always increases or remains the same as new variables are added to the model, without detecting the 
significance of this newly added variable (i.e. the value of r-square never decreases on the addition of new attributes to the model). 
As a result, non-significant attributes can also be added to the model with an increase in the r-square value.
This is because SStot is always constant and the regression model tries to decrease the value of SSres by finding some correlation 
with this new attribute hence the overall value of r-square increases, which can lead to a poor regression model.

# %%
Adjusted R-Squared is an updated version of R-squared which takes account of the number of independent variables while calculating R-squared.
The main problem with R-squared is that the R-Square value always increases with an increase in independent variables irrespective of 
the fact that where the independent variable is contributing to the model or not.
This leads to the model having high variance if the model has a lot of independent variables.

# %%
Adjusted R^2= 1 – ((1−R^2)⋅(n−1) /n-k-1)

# %%
Q3. When is it more appropriate to use adjusted R-squared?

# %%
Ans: Basically Adjusted R^2 penalizes and takes into consideration the number of predictors (Independent Variable) when calculating 
    the fit, so it is advisable to use Adjusted R^2 when comparing models with different numbers of predictors.

# %%
Q4. What are RMSE, MSE, and MAE in the context of regression analysis? How are these metrics
calculated, and what do they represent?

and

Q5. Discuss the advantages and disadvantages of using RMSE, MSE, and MAE as evaluation metrics in
regression analysis.

# %%
Ans: 
    
 
MAE : Mean Absolute Error : It computes by averaging the absolute difference among predicted and actual values of the data set.
                            It is also called L1 Loss. 

    Pros : 1.Easy to use calculation metric. 
           2. It is useful if training data has outlier as MAE does not penalizing high errors caused by outliers. 
           3. It provides an even measure of how well the model is performing. 
    Cons : 1. Sometimes the large error coming from outliers end up being treated as the same as low errors. 
           2.One of the main disadvantages of MAE is that it is not differentiable at zero.
            Many optimization algorithms tend to use differentiation to find the optimum value for parameters in the evaluation metric.
           3. MAE follows a scale-dependent accuracy measure using the same scale as the data being measured. Hence it cannot be used to compare series’ using different measures.

        
        
MSE :        
MSE is one of the most common regression loss functions and an important error metric. 
In Mean Squared Error, also known as L2 loss, 
we calculate the error by squaring the difference between the predicted value and actual value and averaging 
it across the dataset.
MSE is also known as Quadratic loss as the penalty is not proportional to the error but to the square of the error. 
Squaring the error gives higher weight to the outliers, which results in a smooth gradient for small errors.


Pros of the MSE Evaluation Metric
MSE values are expressed in quadratic equations. Hence when we plot it, we get a gradient descent with only one global minima.
For small errors, it converges to the minima efficiently. There are no local minima.
MSE penalizes the model for having huge errors by squaring them.
It is particularly helpful in weeding out outliers with large errors from the model by putting more weight on them.

Cons of the MSE Evaluation Metric
One of the advantages of MSE becomes a disadvantage when there is a bad prediction. The sensitivity to outliers magnifies the high errors by squaring them.
MSE will have the same effect for a single large error as too many smaller errors. But mostly we will be looking for a model which performs well enough on an overall level.
MSE is scale-dependent as its scale depends on the scale of the data. This makes it highly undesirable to compare different measures.
When a new outlier is introduced into the data, the model will try to take in the outlier. By doing so it will produce a different line of best fit which may cause the final results to be skewed.
        

        
        
        
RMSE : Root Mean Square Error : Root mean sqaure error in machine learning is a popular metric used in machine learning 
        and statistics to measure the accuracy of a predictive model. It quantifies the differences between predicted 
        values and actual values, squaring the errors, taking the mean and then finding the sqaure root. RMSE provides a clear 
        understanding of the model's performance, with lower values indicating better predictive accuracy relative root mean 
        square error. 
        it is computed by taking the square root of MSE. 
        RMSE is also called the root mean square deviation. 
        RMSE values with zero indicates perfect model fit.
        
Root Mean Square Error in Machine Learning (RMSE) is a popular metric used in machine learning and statistics to measure the accuracy of a predictive model. It quantifies the differences between predicted values and actual values, squaring the errors, taking the mean, and then finding the square root. RMSE provides a clear understanding of the model’s performance, with lower values indicating better predictive accuracy relative root mean square error.

It is computed by taking the square root of MSE. RMSE is also called the Root Mean Square Deviation. 
        

Pros of the RMSE Evaluation Metric
RMSE is easy to understand.
It serves as a heuristic for training models.
It is computationally simple and easily differentiable which many optimization algorithms desire.
RMSE does not penalize the errors as much as MSE does due to the square root.

Cons of the RMSE Metric
Like MSE, RMSE is dependent on the scale of the data. It increases in magnitude if the scale of the error increases.
One major drawback of RMSE is its sensitivity to outliers and the outliers have to be removed for it to function properly.
RMSE increases with an increase in the size of the test sample. This is an issue when we calculate the results on different test samples.

# %%
Q6. Explain the concept of Lasso regularization. How does it differ from Ridge regularization, and when is
it more appropriate to use?

# %%
While developing machine learning models you must have encountered a situation in which the training accuracy of the model is high but the validation accuracy or the testing accuracy is low. This is the case which is popularly known as overfitting in the domain of machine learning. 
Also, this is the last thing a machine learning practitioner would like to have in his model.

# %%
Regularization in python reduces overfitting. 

In python, regularization is a technique used to prevent overfitting by adding a penalty term to the loss function, 
discouraging the model from assigning too much importance to individual features or coefficients.

# %%
A regression model which uses the L1 regularization is called Lasso  (Least Absolute Shrinkage and Selection Operator)
Regression. Lasso Regression adds 
the penalty as "absolute value of Magnitude" to the loss function.

# %%
Lasso regression also helps us achieve feature selection by penalizing the weights to 
approximately equal to zero if that feature does not serve any purpose in the model.

# %%
cost = 1/n (Yactual - Y predicted) ^ 2 +   Lambda |Wi|

# %%
Link : https://www.analyticsvidhya.com/blog/2016/01/ridge-lasso-regression-python-complete-tutorial/

# %%
Q7. How do regularized linear models help to prevent overfitting in machine learning? Provide an
example to illustrate.

# %%
Regularization is a technique that penalizes the coefficient. In an overfit model, the coefficients are generally inflated. Thus, Regularization adds penalties to the parameters and avoids them weigh heavily. The coefficients are added to the cost function of the linear equation. Thus, if the coefficient inflates, the cost function will increase. 
And Linear regression model will try to optimize the coefficient in order to minimize the cost function

# %%
Practically, you can check if the regression model is overfitting or not by RMSE. A good model has a similar RMSE for the train and test sets. If the difference is too large, we can say the model is overfitting to the training set. 
There are two kinds of techniques for adding penalities to the cost function, L1 Norm or LASSO term and L2 Norm or Ridge Term.

# %%
Q.8 Discuss the limitations of regularized linear models and explain why they may not always be the best
choice for regression analysis.

# %%
Ans:

# %%
Q.9 You are comparing the performance of two regression models using different evaluation metrics.
Model A has an RMSE of 10, while Model B has an MAE of 8. Which model would you choose as the better
performer, and why? Are there any limitations to your choice of metric?

# %%
Ans : 
Model B (with MAE of 8) might be the better choice in many cases because it suggests more consistent performance
with smaller average errors. If you are more concerned with the average error across all predictions and less concerned with extreme outliers, Model B would likely be preferred.

Model A (with RMSE of 10) could be the better choice if you want a model that penalizes larger errors more heavily. 
This could be the case in situations where large errors are particularly costly (e.g., in high-stakes decision-making where even small mistakes can lead to significant consequences).

# %%
If consistency and smaller average errors are more important, Model B with MAE of 8 is likely the better choice.
If you are concerned about large errors and want to penalize them more heavily, Model A with RMSE of 10 might be preferred.

# %%
Q10. You are comparing the performance of two regularized linear models using different types of
regularization. Model A uses Ridge regularization with a regularization parameter of 0.1, while Model B
uses Lasso regularization with a regularization parameter of 0.5. Which model would you choose as the
better performer, and why? Are there any trade-offs or limitations to your choice of regularization
method?

# %%
Ans : Choose Model A (Ridge) if you suspect many features are important and correlated, and you want to maintain all of them with reduced coefficients. It is less likely to underfit compared to Lasso, especially with smaller regularization strengths like 0.1.

Choose Model B (Lasso) if you expect only a few features to be relevant and want to perform automatic feature selection. However, you should be cautious about the regularization strength (
𝜆
=
0.5
λ=0.5)—it might need tuning to avoid underfitting.
